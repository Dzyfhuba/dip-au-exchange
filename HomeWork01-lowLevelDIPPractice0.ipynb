# %% [markdown]
# # Assignment #1: low level DIP practice

# %% [markdown]
# ## Apply the Types of filter as follows:
# - Gaussian blur
# - Median filter
# - Dilation and erosion
# - Customs filters
# - Image thresholding

# %% [markdown]
# First step, I import all modules in the beginning.

# %%
import matplotlib.pyplot as plt
from PIL import Image, ImageFilter, ImageEnhance
from skimage import io, data, filters, color
from skimage.morphology import disk, dilation, erosion
from skimage.util import random_noise, img_as_ubyte
import numpy as np

# %% [markdown]
# I prepare some variables

# %%
img_ski = data.astronaut().astype('uint8')
img_pil = Image.open('astronaut.png')
img_title = "Astronaut"

# %% [markdown]
# ## 1. Gaussian Blur

# %%
fig2 = plt.figure(figsize=(20, 14))

# before: The two variables above have the same image, so I just use one variable
bfr_gau1 = img_ski
fig2.add_subplot(2, 2, 1)
plt.title("Before")
plt.imshow(bfr_gau1)

# using scikit-image
ski_gau = filters.gaussian(img_ski, sigma=4)
fig2.add_subplot(2, 2, 3)
plt.title("After: using scikit-image")
plt.imshow(ski_gau)

# using pillow
pil_gau = img_pil.filter(ImageFilter.GaussianBlur(4))
pil_gau = Image.fromarray(np.array(pil_gau))
fig2.add_subplot(2, 2, 4)
plt.title("After: using pillow")
plt.imshow(pil_gau)
# Out:
# <ipython-input-3-cbeb30e4c2d8>:10: RuntimeWarning: Images with dimensions (M, N, 3) are interpreted as 2D+RGB by default. Use `multichannel=False` to interpret as 3D image with last dimension of length 3.
#   ski_gau = filters.gaussian(img_ski, sigma=4)

# %% [markdown]
# ## 2. Median Filter

# %%
fig3 = plt.figure(figsize=(20,7))

fig3.add_subplot(1, 3, 1)
plt.title("Before")
plt.imshow(img_ski)

# img_ski = np.array(img_ski, dtype = 'uint8')
# ski_medfil = filters.rank.median(img_ski, disk(1))
# fig3.add_subplot(1, 3, 2)
# plt.title('scikit image median filter')
# plt.imshow(img_ski)

#using pillow
pil_medfil = Image.fromarray(img_ski).filter(ImageFilter.MedianFilter(7))
fig3.add_subplot(1, 3, 3)
plt.title('After: using pillow')
plt.imshow(pil_medfil)

# %% [markdown]
# ## 3. Dilation and Erosion

# %%
fig4 = plt.figure(figsize=(20, 19))

fig4.add_subplot(2, 2, 1)
plt.title('Before')
plt.imshow(img_ski)

# using scikit-image
dilated_ski = dilation(img_ski)
fig4.add_subplot(2, 2, 2)
plt.title('After: Dilation using scikit-image')
plt.imshow(dilated_ski)

fig4.add_subplot(2, 2, 3)
plt.title('Before')
plt.imshow(img_ski)

eroded_ski = erosion(img_ski)
fig4.add_subplot(2, 2, 4)
plt.title('After: Erosion using scikit-image')
plt.imshow(eroded_ski)

# %% [markdown]
# ## 4. Custom Filters

# %%
fig5 = plt.figure(figsize=(20, 19))

fig5.add_subplot(2, 3, 1)
plt.title('Before')
plt.imshow(img_ski)

# using pillow
custom_pil1 = img_pil.filter(ImageFilter.UnsharpMask())
fig5.add_subplot(2, 3, 2)
plt.title('After: 1st filter using pillow')
plt.imshow(custom_pil1)

custom_pil2 = custom_pil1.filter(ImageFilter.BoxBlur(4))
fig5.add_subplot(2, 3, 3)
plt.title('After: 2nd filter using pillow')
plt.imshow(custom_pil2)

# fig5.add_subplot(2, 3, 4)
# plt.title('Before')
# plt.imshow(img_pil)

# # using scikit-image
# custom_ski1 = filters.gaussian(img_ski, sigma=2)
# fig5.add_subplot(2, 3, 5)
# plt.title('After: 1st filter using scikit-image')
# plt.imshow(custom_ski1)

# %% [markdown]
# ## 5. Image Thresholding
