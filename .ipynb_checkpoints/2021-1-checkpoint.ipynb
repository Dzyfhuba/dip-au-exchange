# %%
from PIL import Image #4-1-1 push the shift and enter at the same time

# %%
img = Image.open("astronaut.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-f84c671d607b> in <module>
# ----> 1 img = Image.open("astronaut.png")
#
# E:\H\conda\envs\dip\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2902
#    2903     if filename:
# -> 2904         fp = builtins.open(filename, "rb")
#    2905         exclusive_fp = True
#    2906
#
# FileNotFoundError: [Errno 2] No such file or directory: 'astronaut.png'

# %%
img.show()

# %%
print (img.size)
# Out:
# (318, 318)

# %%
dim = (100,100,300,300) # Dimensiions of the ROI #4-1-3

# %%
crop_img = img.crop(dim) #image crop 4-1-3

# %%
crop_img.show() # show image crop

# %%
greyscale = img.convert("L") # color to gray 4-1-4

# %%
greyscale.show() #show the gray image

# %% [raw]
# img.save("G:/Computer Vision/astronaut2.png") #4-1-2

# %%
resize_img = img.resize((256,256))

# %% [raw]
# img=Image.open("E:/Computer Vision/astronaut2.png")

# %%
resize_img.show()

# %%
img.show()

# %%
print (img.size) # check the image size
# Out:
# (660, 389)

# %%
resize_img = img.resize((660,389))

# %%
resize_img.show()

# %%
resize_img = img.resize((330,200))

# %%
resize_img.show()

# %%
from PIL import Image

# %%
img = Image.open("G:/Computer Vision/lena.png") #4-1-6

# %%
img.show()

# %%
print (img.size)
# Out:
# (128, 128)

# %%
resize_img = img.resize((256,256)) # 4-1-5

# %%
resize_img.show()

# %%
resize_img.save("F:/Computer Vision/lena2.png") #4-1-6
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4acba03e9ee6> in <module>
# ----> 1 resize_img.save("F:/Computer Vision/lena2.png") #4-1-6
#
# NameError: name 'resize_img' is not defined

# %%
rotate_img = img.rotate(90)

# %%
rotate_img.show()

# %%
img = Image.open("E:/Computer Vision/newastronaut.png")

# %%
img.show()

# %%
from PIL import ImageEnhance # 3-1-7 import ImageEnhance module from PIL

# %%
enhancer = ImageEnhance.Brightness(img) # enhance the rightness of img to create a new image named enhancer

# %%
enhancer.enhance(2).show() # a factor value greater than 1 will increase the brightness

# %%
enhancer.enhance(0.5).show() # a factor value less than 1 will decrease the brightness

# %%
print (img.size)
# Out:
# (660, 389)

# %%
 img = Image.open("G:/Computer Vision/astronaut.png")

# %%
print (img.size)
# Out:
# (318, 318)

# %%
img.show()

# %%
img.getpixel((355,443))
# Out:
# (254, 254, 254)

# %%
img.getpixel((239,293))
# Out:
# (254, 254, 254)

# %%
img.show()

# %%
import numpy as np #3-2-2

# %%
import scipy as sp

# %%
import matplotlib.pyplot as plt

# %%
from skimage import io

# %%
img = io.imread("F:/Computer Vision/newastronaut.png")

# %%
io.imshow("F:/Computer Vision/newastronaut.png")

# %%
print(img.shape)
# Out:
# (512, 512, 3)

# %%
plt.imshow(img)# another option to show the image

# %%
plt.show()

# %%
io.imshow(img)

# %%
from skimage import io, data #3-2-4

# %%
io.imshow(data.camera()) # show the image stored in data library

# %%
io.imshow(data.text())

# %%
io.imshow(data.hubble_deep_field())

# %%
img = data.hubble_deep_field()

# %%
img = data.hubble_deep_field()io.imshow(img)

# %%
io.imsave('F:/Computer Vision/hubble.jpg', img)

# %%
img.show()

# %%
print(img.size)
# Out:
# (318, 318)

# %%
img = io.imread("G:/Computer Vision/astronaut.png")

# %%
print(img.shape)
# Out:
# (318, 318, 3)

# %%
io.imshow(img)

# %%
from skimage import io, color #

# %%
img = io.imread("F:/Computer Vision/astronaut.png")

# %%
gray = color.rgb2gray(img) #3-2-5

# %%
io.imshow(gray)

# %%
img = data.astronaut()

# %%
io.imshow(img)

# %%
print(img.size)
# Out:
# 786432

# %%
print(img.shape)
# Out:
# (512, 512, 3)

# %%
io.imsave("G:/Computer Vision/newastronaut.png", img)

# %%
img = data.binary_blobs()

# %%
io.imshow(img)

# %%
io.imsave("G:/Computer Vision/newbinary_blobs.png", img)
# Out:
# C:\Users\aaa\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: G:/Computer Vision/newbinary_blobs.png is a boolean image: setting True to 255 and False to 0. To silence this warning, please convert the image using img_as_ubyte.
#   """Entry point for launching an IPython kernel.

# %%
img = data.camera()

# %%
io.imshow(img)

# %%
io.imsave("G:/Computer Vision/newcamera.png", img)

# %%
img = data.checkerboard()

# %%
io.imshow(img)

# %%
io.imsave("G:/Computer Vision/newcheckeroard.png", img)

# %%
img = data.chelsea()

# %%
io.imshow(img)

# %%
io.imsave("G:/Computer Vision/chelsea.png", img)

# %%
img = data.clock()

# %%
io.imshow(img)

# %%
io.imsave("G:/Computer Vision/newclock.png", img)

# %%
from skimage import io # 3-2-6

# %%
from skimage import color

# %%
from skimage import filters

# %%
img = io.imread("F:/Computer Vision/newastronaut.png")

# %%
img = color.rgb2gray(img)

# %%
edge = filters.sobel(img)

# %%
io.imshow(edge)

# %%
import PIL
print('PIL',PIL.__version__)
# Out:
# PIL 5.3.0

# %%
img.getpixel((355,443))
# Out:
# (254, 254, 254)
